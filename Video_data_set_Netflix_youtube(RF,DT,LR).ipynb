# %% [markdown]
# <a href="https://colab.research.google.com/github/m17moud/Supervised-Learning/blob/main/Video_data_set_Netflix_youtube(RF%2CDT%2CLR).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Data Link** -->* https://www.kaggle.com/datasets/aminmb2800/per-title-encoding*

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import VotingRegressor
from sklearn.metrics import mean_squared_error , r2_score
from scipy import stats

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10570 entries, 0 to 10569
# Data columns (total 43 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   s_video_id                                            10570 non-null  int64
#  1   s_width                                               10570 non-null  int64
#  2   s_height                                              10570 non-null  int64
#  3   s_storage_size                                        10570 non-null  int64
#  4   s_duration                                            10570 non-null  int64
#  5   s_scan_type                                           10570 non-null  object
#  6   c_content_category                                    10323 non-null  object
#  7   c_si                                                  9764 non-null   float64
#  8   c_ti                                                  9764 non-null   float64
#  9   c_scene_change_ffmpeg_ratio30                         10570 non-null  float64
#  10  c_scene_change_ffmpeg_ratio60                         10570 non-null  float64
#  11  c_scene_change_ffmpeg_ratio90                         10570 non-null  float64
#  12  c_scene_change_py_thresh30                            10570 non-null  float64
#  13  c_scene_change_py_thresh50                            10570 non-null  float64
#  14  c_colorhistogram_mean_dark                            10414 non-null  float64
#  15  c_colorhistogram_mean_medium_dark                     10414 non-null  float64
#  16  c_colorhistogram_mean_medium_bright                   10414 non-null  float64
#  17  c_colorhistogram_mean_bright                          10414 non-null  float64
#  18  c_colorhistogram_std_dev_dark                         10414 non-null  float64
#  19  c_colorhistogram_std_dev_medium_dark                  10414 non-null  float64
#  20  c_colorhistogram_std_dev_medium_bright                10414 non-null  float64
#  21  c_colorhistogram_std_dev_bright                       10414 non-null  float64
#  22  c_colorhistogram_temporal_mean_std_dev_dark           10414 non-null  float64
#  23  c_colorhistogram_temporal_mean_std_dev_medium_dark    10414 non-null  float64
#  24  c_colorhistogram_temporal_mean_std_dev_medium_bright  10414 non-null  float64
#  25  c_colorhistogram_temporal_mean_std_dev_bright         10414 non-null  float64
#  26  e_crf                                                 10570 non-null  int64
#  27  e_width                                               10570 non-null  int64
#  28  e_height                                              10570 non-null  int64
#  29  e_aspect_ratio                                        10570 non-null  object
#  30  e_pixel_aspect_ratio                                  10570 non-null  object
#  31  e_codec                                               10391 non-null  object
#  32  e_codec_profile                                       10391 non-null  object
#  33  e_codec_level                                         10391 non-null  float64
#  34  e_framerate                                           10391 non-null  float64
#  35  e_gop_size                                            10391 non-null  float64
#  36  e_b_frame_int                                         10570 non-null  int64
#  37  e_ref_frame_count                                     10391 non-null  float64
#  38  e_scan_type                                           10570 non-null  object
#  39  e_bit_depth                                           10379 non-null  float64
#  40  e_pixel_fmt                                           10391 non-null  object
#  41  t_average_bitrate                                     10570 non-null  int64
#  42  t_average_vmaf                                        10178 non-null  float64
# dtypes: float64(25), int64(10), object(8)
# memory usage: 3.5+ MB

# %%
missing_values = data.isnull().sum()
print("Missing Values Before Handling:")
print(missing_values[missing_values > 0])

numerical_cols = data.select_dtypes(include=['float64', 'int64']).columns
data[numerical_cols] = data[numerical_cols].fillna(data[numerical_cols].mean())

categorical_cols = data.select_dtypes(include=['object']).columns
for col in categorical_cols:
    if data[col].isnull().any():  # Check if there are any nulls
        mode_value = data[col].mode()[0]
        data[col].fillna(mode_value, inplace=True)
        print(f"Filled missing values in {col} with mode: {mode_value}")

drop_cols = ['t_average_vmaf_mobile', 't_average_vmaf_4k', 't_average_psnr']
data.drop(columns=drop_cols, inplace=True, errors='ignore')

remaining_missing_values = data.isnull().sum()
print("\nRemaining Missing Values After Handling:")
print(remaining_missing_values[remaining_missing_values > 0])
# Out:
# Missing Values Before Handling:
# c_content_category                                      247
# c_si                                                    806
# c_ti                                                    806
# c_colorhistogram_mean_dark                              156
# c_colorhistogram_mean_medium_dark                       156
# c_colorhistogram_mean_medium_bright                     156
# c_colorhistogram_mean_bright                            156
# c_colorhistogram_std_dev_dark                           156
# c_colorhistogram_std_dev_medium_dark                    156
# c_colorhistogram_std_dev_medium_bright                  156
# c_colorhistogram_std_dev_bright                         156
# c_colorhistogram_temporal_mean_std_dev_dark             156
# c_colorhistogram_temporal_mean_std_dev_medium_dark      156
# c_colorhistogram_temporal_mean_std_dev_medium_bright    156
# c_colorhistogram_temporal_mean_std_dev_bright           156
# e_codec                                                 179
# e_codec_profile                                         179
# e_codec_level                                           179
# e_framerate                                             179
# e_gop_size                                              179
# e_ref_frame_count                                       179
# e_bit_depth                                             191
# e_pixel_fmt                                             179
# t_average_vmaf                                          392
# dtype: int64
# Filled missing values in c_content_category with mode: ski
# Filled missing values in e_codec with mode: h264
# Filled missing values in e_codec_profile with mode: main
# Filled missing values in e_pixel_fmt with mode: yuv420p
#
# Remaining Missing Values After Handling:
# Series([], dtype: int64)

# %%
data.isnull().sum()
# Out:
# s_video_id                                              0
# s_width                                                 0
# s_height                                                0
# s_storage_size                                          0
# s_duration                                              0
# s_scan_type                                             0
# c_content_category                                      0
# c_si                                                    0
# c_ti                                                    0
# c_scene_change_ffmpeg_ratio30                           0
# c_scene_change_ffmpeg_ratio60                           0
# c_scene_change_ffmpeg_ratio90                           0
# c_scene_change_py_thresh30                              0
# c_scene_change_py_thresh50                              0
# c_colorhistogram_mean_dark                              0
# c_colorhistogram_mean_medium_dark                       0
# c_colorhistogram_mean_medium_bright                     0
# c_colorhistogram_mean_bright                            0
# c_colorhistogram_std_dev_dark                           0
# c_colorhistogram_std_dev_medium_dark                    0
# c_colorhistogram_std_dev_medium_bright                  0
# c_colorhistogram_std_dev_bright                         0
# c_colorhistogram_temporal_mean_std_dev_dark             0
# c_colorhistogram_temporal_mean_std_dev_medium_dark      0
# c_colorhistogram_temporal_mean_std_dev_medium_bright    0
# c_colorhistogram_temporal_mean_std_dev_bright           0
# e_crf                                                   0
# e_width                                                 0
# e_height                                                0
# e_aspect_ratio                                          0
# e_pixel_aspect_ratio                                    0
# e_codec                                                 0
# e_codec_profile                                         0
# e_codec_level                                           0
# e_framerate                                             0
# e_gop_size                                              0
# e_b_frame_int                                           0
# e_ref_frame_count                                       0
# e_scan_type                                             0
# e_bit_depth                                             0
# e_pixel_fmt                                             0
# t_average_bitrate                                       0
# t_average_vmaf                                          0
# dtype: int64

# %%
plt.figure(figsize=(12, 6))
sns.heatmap(data.isnull(), cbar=False, cmap='viridis')
plt.title('Missing Data Heatmap')
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.histplot(data['t_average_vmaf'], kde=True, color='blue')
plt.title('Distribution of t_average_vmaf')
plt.show()

# %%
numeric_columns = data.select_dtypes(include=[np.number]).columns.tolist()
plt.figure(figsize=(15, 12))
data[numeric_columns].boxplot()
plt.xticks(rotation=90)
plt.title('Boxplots to Identify Outliers in Numerical Features')
plt.show()

# %%
target_column = 't_average_vmaf'

if target_column not in data.columns:
    raise ValueError(f"The target column '{target_column}' is not in the dataset.")

X = data.drop(columns=[target_column])
y = data[target_column]

print("\nShape of Features (X) and Target (y):")
print(f"X shape: {X.shape}, y shape: {y.shape}")

X = pd.get_dummies(X, drop_first=True)

print("\nShape of Features after Encoding:")
print(X.shape)

if X.empty:
    raise ValueError("X is empty after encoding. Please check your feature selection.")


scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
# Out:
# Shape of Features (X) and Target (y):
# X shape: (10570, 42), y shape: (10570,)
#
# Shape of Features after Encoding:
# (10570, 98)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
numeric_columns = data.select_dtypes(include=[np.number]).columns.tolist()
plt.figure(figsize=(15, 12))
data[numeric_columns].boxplot()
plt.xticks(rotation=90)
plt.title('Boxplots to Identify Outliers in Numerical Features')
plt.show()

# %%
model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
y_pred = model.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("\nModel Evaluation:")
print(f"Mean Squared Error: {mse:.2f}")
print(f"R^2 Score: {r2:.2f}")
# Out:
# Model Evaluation:
# Mean Squared Error: 11.12
# R^2 Score: 0.99

# %%
feature_importances = model.feature_importances_
indices = np.argsort(feature_importances)[::-1]

plt.figure(figsize=(12, 6))
plt.title("Feature Importances")
plt.bar(range(X.shape[1]), feature_importances[indices], align="center")
plt.xticks(range(X.shape[1]), X.columns[indices], rotation=90)
plt.xlim([-1, X.shape[1]])
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=y_test, y=y_pred)
plt.plot([y.min(), y.max()], [y.min(), y.max()], 'r--')
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Actual vs Predicted Values(Random Forest)")
plt.show()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor

# %%
linear_model = LinearRegression()
linear_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = linear_model.predict(X_test)

# %%
r2 = r2_score(y_test, y_pred)

print("\nModel Evaluation:")
print(f"R^2 Score: {r2:.2f}")
# Out:
# Model Evaluation:
# R^2 Score: 0.90

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=y_test, y=y_pred)
plt.plot([y.min(), y.max()], [y.min(), y.max()], 'r--')
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Actual vs Predicted Values(Linear Regression)")
plt.show()

# %%
tree_model = DecisionTreeRegressor(random_state=42)
tree_model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(random_state=42)

# %%
y_pred = tree_model.predict(X_test)

# %%
r2 = r2_score(y_test, y_pred)

print("\nModel Evaluation:")
print(f"R^2 Score: {r2:.2f}")
# Out:
# Model Evaluation:
# R^2 Score: 0.97

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=y_test, y=y_pred)
plt.plot([y.min(), y.max()], [y.min(), y.max()], 'r--')
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Actual vs Predicted Values (Decision Tree)")
plt.show()
